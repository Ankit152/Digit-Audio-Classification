# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import IPython.display as ipd

# %%
# creating the metadata
recordings="./data/"
lst=[]
for i in range(10):
    ndir=recordings+str(i)+"/"
    for file in os.listdir(ndir):
        lst.append([ndir,file,i])

# %%
lst[0:4]
# Out:
# [['./data/0/', '0_george_0.wav', 0],
#  ['./data/0/', '0_george_1.wav', 0],
#  ['./data/0/', '0_george_10.wav', 0],
#  ['./data/0/', '0_george_11.wav', 0]]

# %%
print(len(lst))
# Out:
# 3000

# %%
metadata=pd.DataFrame(lst,columns=['absPath','fileName','label'],index=None)
metadata.head()
# Out:
#      absPath         fileName  label
# 0  ./data/0/   0_george_0.wav      0
# 1  ./data/0/   0_george_1.wav      0
# 2  ./data/0/  0_george_10.wav      0
# 3  ./data/0/  0_george_11.wav      0
# 4  ./data/0/  0_george_12.wav      0

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=metadata['label'])
plt.xlabel('Digits',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Countplot of Digits Audio',fontsize=20)
plt.savefig('./img/countplotAudio.png')
plt.show()

# %%
filename="./data/0/0_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Zero",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/0.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/1/1_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of One",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/1.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/2/2_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Two",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/2.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/3/3_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Three",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/3.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/4/4_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Four",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/4.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/5/5_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Five",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/5.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/6/6_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Six",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/6.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/7/7_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Seven",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/7.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/8/8_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Eight",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/8.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename="./data/9/9_george_0.wav"
plt.figure(figsize=(15,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
plt.title("Waveplot of Nine",fontsize=20)
plt.xlabel("Time",fontsize=15)
plt.ylabel("Amplitude",fontsize=15)
plt.savefig("./img/9.png")
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
